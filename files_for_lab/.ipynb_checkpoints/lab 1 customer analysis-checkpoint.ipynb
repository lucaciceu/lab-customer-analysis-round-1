# %%
import pandas as pd
import numpy as np

# %%
# import the 3 files into pandas DFs
df1 = pd.read_csv('file1.csv')
df2 = pd.read_csv('file2.csv')
df3 = pd.read_csv('file3.csv')

# %%
# to display the dataframe 1
df1
# Out:
#      Customer          ST GENDER             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
# to display the dataframe 2
df2
# Out:
#     Customer          ST GENDER Education Customer Lifetime Value  Income  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1    CW49887  California      F    Master              462680.11%   79487
# 2    MY31220  California      F   College              899704.02%   54230
# 3    UH35128      Oregon      F   College             2580706.30%   71210
# 4    WH52799     Arizona      F   College              380812.21%   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master              847141.75%   63513
# 992  BS91566     Arizona      F   College              543121.91%   58161
# 993  IL40123      Nevada      F   College              568964.41%   83640
# 994  MY32149  California      F    Master              368672.38%       0
# 995  SA91515  California      M  Bachelor              399258.39%       0
#
#      Monthly Premium Auto Number of Open Complaints  Total Claim Amount  \
# ...

# %%
# to display the dataframe 2
df3
# Out:
#      Customer       State  Customer Lifetime Value             Education  \
# 0     SA25987  Washington              3479.137523  High School or Below
# 1     TB86706     Arizona              2502.637401                Master
# 2     ZL73902      Nevada              3265.156348              Bachelor
# 3     KX23516  California              4455.843406  High School or Below
# 4     FN77294  California              7704.958480  High School or Below
# ...       ...         ...                      ...                   ...
# 7065  LA72316  California             23405.987980              Bachelor
# 7066  PK87824  California              3096.511217               College
# 7067  TD14365  California              8163.890428              Bachelor
# 7068  UP19263  California              7524.442436               College
# 7069  Y167826  California              2611.836866               College
#
#      Gender  Income  Monthly Premium Auto  Number of Open Complaints  \
# ...

# %%
# to display the dataframe 1 shape
df1.shape
# Out:
# (4008, 11)

# %%
# to display the dataframe 2 shape
df2.shape
# Out:
# (996, 11)

# %%
# to display the dataframe 3 shape
df3.shape
# Out:
# (7070, 11)

# %%
#viewing the headers for df1
df1.columns
# Out:
# Index(['Customer', 'ST', 'GENDER', 'Education', 'Customer Lifetime Value',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Policy Type', 'Vehicle Class', 'Total Claim Amount'],
#       dtype='object')

# %%
#viewing the headers for df2
df2.columns
# Out:
# Index(['Customer', 'ST', 'GENDER', 'Education', 'Customer Lifetime Value',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Total Claim Amount', 'Policy Type', 'Vehicle Class'],
#       dtype='object')

# %%
#viewing the headers for df3
df3.columns
# Out:
# Index(['Customer', 'State', 'Customer Lifetime Value', 'Education', 'Gender',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Policy Type', 'Total Claim Amount', 'Vehicle Class'],
#       dtype='object')

# %%
#making sure all coluns are in lower case
df1.columns = df1.columns.str.lower()
df2.columns = df2.columns.str.lower()
df3.columns = df3.columns.str.lower()

#replacing 'ST' with 'state' for df1, df2
df1 = df1.rename(columns={'st':'state'})
df2 = df2.rename(columns={'st':'state'})

#verifying for df1
df1.columns
# Out:
# Index(['customer', 'state', 'gender', 'education', 'customer lifetime value',
#        'income', 'monthly premium auto', 'number of open complaints',
#        'policy type', 'vehicle class', 'total claim amount'],
#       dtype='object')

# %%
# rearranging columns for df2 & df3 to have the same header as df1
df2 = df2[['customer', 'state', 'gender', 'education', 'customer lifetime value',
       'income', 'monthly premium auto', 'number of open complaints',
       'policy type', 'vehicle class', 'total claim amount']]
df3 = df3[['customer', 'state', 'gender', 'education', 'customer lifetime value',
       'income', 'monthly premium auto', 'number of open complaints',
       'policy type', 'vehicle class', 'total claim amount']]

#checking for df3
df3.columns
# Out:
# Index(['customer', 'state', 'gender', 'education', 'customer lifetime value',
#        'income', 'monthly premium auto', 'number of open complaints',
#        'policy type', 'vehicle class', 'total claim amount'],
#       dtype='object')

# %%
#concatenate the files
df_total=pd.concat([df1, df2, df3])

#verifying
df_total.shape
# Out:
# (12074, 11)

# %%
#showing data frame column types
df_total.dtypes
# Out:
# customer                      object
# state                         object
# gender                        object
# education                     object
# customer lifetime value       object
# income                       float64
# monthly premium auto         float64
# number of open complaints     object
# policy type                   object
# vehicle class                 object
# total claim amount           float64
# dtype: object

# %%
#listing categorical columns
list_categorical_types = list(df_total.select_dtypes(include=['object']).columns)
list_categorical_types
# Out:
# ['customer',
#  'state',
#  'gender',
#  'education',
#  'customer lifetime value',
#  'number of open complaints',
#  'policy type',
#  'vehicle class']

# %%
#listing numerical columns
list_numeric_types = list(df_total.select_dtypes(include=['float64']).columns)
list_numeric_types
# Out:
# ['income', 'monthly premium auto', 'total claim amount']

# %%
# deleting columns 'number of open complaints', 'education'
df_total = df_total.drop(['number of open complaints', 'education'], 1)
df_total.columns
# Out:
# Index(['customer', 'state', 'gender', 'customer lifetime value', 'income',
#        'monthly premium auto', 'policy type', 'vehicle class',
#        'total claim amount'],
#       dtype='object')

# %%
df_total['customer lifetime value']
# Out:
# 0                NaN
# 1         697953.59%
# 2        1288743.17%
# 3         764586.18%
# 4         536307.65%
#             ...
# 7065    23405.987980
# 7066     3096.511217
# 7067     8163.890428
# 7068     7524.442436
# 7069     2611.836866
# Name: customer lifetime value, Length: 12074, dtype: object

# %%
#checking for null values
df_total[df_total['customer lifetime value'].isna()==True]
# Out:
#      customer       state gender customer lifetime value   income  \
# 0     RB50392  Washington    NaN                     NaN      0.0
# 78    SP81997  Washington      F                     NaN  41275.0
# 988   GT62080  Washington      M                     NaN  55561.0
# 1071      NaN         NaN    NaN                     NaN      NaN
# 1072      NaN         NaN    NaN                     NaN      NaN
# ...       ...         ...    ...                     ...      ...
# 4007      NaN         NaN    NaN                     NaN      NaN
# 325   RI52095  Washington      M                     NaN  51878.0
# 372   HF88410  Washington    NaN                     NaN  36765.0
# 580   MW80236  Washington      M                     NaN      0.0
# 861   TO60700  Washington      F                     NaN  25859.0
#
#       monthly premium auto    policy type  vehicle class  total claim amount
# 0                   1000.0  Personal Auto  Four-Door Car            2.704934
# ...

# %%
#checking the percentage of null values
df_total['customer lifetime value'].isna().sum()/len(df_total)*100
# Out:
# 24.382971674672852

# %%
#converting to string
df_total['customer lifetime value'].to_string()
#removing %
df_total['customer lifetime value'] = df_total['customer lifetime value'].str.replace('%','')
#converting null fields to zero
df_total['customer lifetime value'] = df_total['customer lifetime value'].fillna(0)
df_total['customer lifetime value']
# Out:
# 0                0
# 1        697953.59
# 2       1288743.17
# 3        764586.18
# 4        536307.65
#            ...
# 7065             0
# 7066             0
# 7067             0
# 7068             0
# 7069             0
# Name: customer lifetime value, Length: 12074, dtype: object

# %%
#cloning the df 
df_total_v2 = df_total.copy()
#converting the cloned df to numeric
df_total_v2['customer lifetime value']=pd.to_numeric(df_total_v2['customer lifetime value'], errors='coerce')
df_total_v2['customer lifetime value']
# Out:
# 0             0.00
# 1        697953.59
# 2       1288743.17
# 3        764586.18
# 4        536307.65
#            ...
# 7065          0.00
# 7066          0.00
# 7067          0.00
# 7068          0.00
# 7069          0.00
# Name: customer lifetime value, Length: 12074, dtype: float64

# %%
#multiplying the values in the column by 100
df_total_v2['customer lifetime value']=100*df_total_v2['customer lifetime value']
df_total_v2
# Out:
#      customer       state gender  customer lifetime value   income  \
# 0     RB50392  Washington    NaN             0.000000e+00      0.0
# 1     QZ44356     Arizona      F             6.979536e+09      0.0
# 2     AI49188      Nevada      F             1.288743e+10  48767.0
# 3     WW63253  California      M             7.645862e+09      0.0
# 4     GA49547  Washington      M             5.363076e+09  36357.0
# ...       ...         ...    ...                      ...      ...
# 7065  LA72316  California      M             0.000000e+00  71941.0
# 7066  PK87824  California      F             0.000000e+00  21604.0
# 7067  TD14365  California      M             0.000000e+00      0.0
# 7068  UP19263  California      M             0.000000e+00  21941.0
# 7069  Y167826  California      M             0.000000e+00      0.0
#
#       monthly premium auto     policy type  vehicle class  total claim amount
# 0                   1000.0   Personal Auto  Four-Door Car            2.704934
# ...

# %%
#checking for duplicates (sum)
df_total_v2.duplicated().sum()
# Out:
# 2943

# %%
#checking the duplicates
df_total_v2[df_total_v2.duplicated() == True]
# Out:
#      customer       state gender  customer lifetime value   income  \
# 1072      NaN         NaN    NaN             0.000000e+00      NaN
# 1073      NaN         NaN    NaN             0.000000e+00      NaN
# 1074      NaN         NaN    NaN             0.000000e+00      NaN
# 1075      NaN         NaN    NaN             0.000000e+00      NaN
# 1076      NaN         NaN    NaN             0.000000e+00      NaN
# ...       ...         ...    ...                      ...      ...
# 2     MY31220  California      F             8.997040e+09  54230.0
# 998   TO60700  Washington      F             0.000000e+00  25859.0
# 1471  RI52095  Washington      M             0.000000e+00  51878.0
# 1487  MW80236  Washington      M             0.000000e+00      0.0
# 1535  SP81997  Washington      F             0.000000e+00  41275.0
#
#       monthly premium auto    policy type  vehicle class  total claim amount
# 1072                   NaN            NaN            NaN                 NaN
# ...

# %%
#droping duplicates
df_total_dropped_duplicates = df_total_v2.drop_duplicates()
df_total_dropped_duplicates
# Out:
#      customer       state gender  customer lifetime value   income  \
# 0     RB50392  Washington    NaN             0.000000e+00      0.0
# 1     QZ44356     Arizona      F             6.979536e+09      0.0
# 2     AI49188      Nevada      F             1.288743e+10  48767.0
# 3     WW63253  California      M             7.645862e+09      0.0
# 4     GA49547  Washington      M             5.363076e+09  36357.0
# ...       ...         ...    ...                      ...      ...
# 7065  LA72316  California      M             0.000000e+00  71941.0
# 7066  PK87824  California      F             0.000000e+00  21604.0
# 7067  TD14365  California      M             0.000000e+00      0.0
# 7068  UP19263  California      M             0.000000e+00  21941.0
# 7069  Y167826  California      M             0.000000e+00      0.0
#
#       monthly premium auto     policy type  vehicle class  total claim amount
# 0                   1000.0   Personal Auto  Four-Door Car            2.704934
# ...

# %%
#filtered by income 0 or negative
filtered_less_0 = df_total_dropped_duplicates[(df_total_dropped_duplicates['income']<=0)]
filtered_less_0
# Out:
#      customer       state gender  customer lifetime value  income  \
# 0     RB50392  Washington    NaN             0.000000e+00     0.0
# 1     QZ44356     Arizona      F             6.979536e+09     0.0
# 3     WW63253  California      M             7.645862e+09     0.0
# 7     CF85061     Arizona      M             7.216100e+09     0.0
# 10    SX51350  California      M             4.738992e+09     0.0
# ...       ...         ...    ...                      ...     ...
# 7059  WZ45103  California      F             0.000000e+00     0.0
# 7061  RX91025  California      M             0.000000e+00     0.0
# 7062  AC13887  California      M             0.000000e+00     0.0
# 7067  TD14365  California      M             0.000000e+00     0.0
# 7069  Y167826  California      M             0.000000e+00     0.0
#
#       monthly premium auto     policy type  vehicle class  total claim amount
# 0                   1000.0   Personal Auto  Four-Door Car            2.704934
# ...
